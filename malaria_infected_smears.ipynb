# %% [markdown]
# <a href="https://colab.research.google.com/github/tommarvoloriddle/Coursera---Convolutional-Neural-Networks-deeplearning.ai-/blob/main/malaria_infected_smears.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --single-branch --branch malaria_dataset https://github.com/VaranRohila/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 28850 (delta 4), reused 4 (delta 3), pack-reused 28843
# Receiving objects: 100% (28850/28850), 476.04 MiB | 33.14 MiB/s, done.
# Resolving deltas: 100% (20471/20471), done.
# Checking out files: 100% (7148/7148), done.

# %%
# %cd datasets/
# Out:
# /content/datasets

# %%
# !pip3 install tensorflow_datasets

# %%
import tensorflow_datasets as tfds
ds, ds_info = tfds.load('malaria_infected_smears', split='train', with_info=True)
# Out:
# ...
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/malaria_infected_smears/1.0.0.incomplete7STX2N/malaria_infected_smears-train.tfrecord
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/malaria_infected_smears/1.0.0.incomplete7STX2N/malaria_infected_smears-test.tfrecord
# ...
# ERROR:absl:Statistics generation doesn't work for nested structures yet
# ...
# ERROR:absl:Statistics generation doesn't work for nested structures yet
# Dataset malaria_infected_smears downloaded and prepared to /root/tensorflow_datasets/malaria_infected_smears/1.0.0. Subsequent calls will reuse this data.

# %%
tfds.ReadConfig()
# Out:
# ReadConfig(options=<tensorflow.python.data.ops.dataset_ops.Options object at 0x7efc148c7590>, try_autocache=True, shuffle_seed=None, shuffle_reshuffle_each_iteration=None, interleave_parallel_reads=16, interleave_block_length=16, experimental_interleave_sort_fn=None)
